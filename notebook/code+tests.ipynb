# %%
import pandas as pd
import json

# %%
data = pd.read_csv("..\\Network_Data\phisingData.csv")
data.T
# Out:
#                              0      1      2      3      4      5      6      \
# having_IP_Address               -1      1      1      1      1     -1      1
# URL_Length                       1      1      0      0      0      0      0
# Shortining_Service               1      1      1      1     -1     -1     -1
# having_At_Symbol                 1      1      1      1      1      1      1
# double_slash_redirecting        -1      1      1      1      1     -1      1
# Prefix_Suffix                   -1     -1     -1     -1     -1     -1     -1
# having_Sub_Domain               -1      0     -1     -1      1      1     -1
# SSLfinal_State                  -1      1     -1     -1      1      1     -1
# Domain_registeration_length     -1     -1     -1      1     -1     -1      1
# Favicon                          1      1      1      1      1      1      1
# port                             1      1      1      1      1      1      1
# ...

# %% [markdown]
# .to_json() converts to JSON string output in form {"ColumnName": {"0": val, "1": val}}
# json.loads(json_data) converts into Python dictionary of dictionary
#
# Hence Transpose is important for correct MongoDB Format. MongoDB -> Document oriented Format

# %%
records = list(json.loads(data.T.to_json()).values())
len(records)      # 11055 columns in data.T hence 11055 items in list
# Out:
# 11055

# %%
# Out:
#   Cell In[8], line 3
#     SCHEMA_FILE_PATH = os.path.join("c:\AI\NETWORKSECURITY\schema_file","schema.yaml")
#                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 5-6: malformed \N character escape
